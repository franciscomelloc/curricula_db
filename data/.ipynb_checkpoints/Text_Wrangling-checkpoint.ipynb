# %% [markdown]
# ## Natural Language Processing Analysis of State's Curricula in Brazil
#
# ### Step 01 : Text Wrangling
#
# Cleanning the data:
#
# Tokenizing
# Tagger
# Parser
# Ner
#
# Remove Punctuation

# %%
import spacy
import numpy as np
import pandas as pd
import seaborn as sns
import os
import glob

from string import punctuation
from collections import Counter

import regex as re

# %%
import nltk
nltk.download('words')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Francisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Francisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Francisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Francisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Francisco\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
# Setup in Brazilian Portuguese

import pt_core_news_sm
nlp = pt_core_news_sm.load()
path = r'C:\Users\Francisco\Desktop\Python\0. TCC ANALYSIS\Corpus\*.txt'
nlp.max_length = 5384682

# %%
# Setting .txt as a Corpus

for file in glob.glob(path):
    with open(file, encoding='utf-8', errors='ignore') as file_in:
        text = file_in.read()
        lines = text.split('\n')
        for line in lines:
            line = nlp(line)

# %% [markdown]
# Next chunk will have spaCy apply its entire NLP "pipeline" to the text as soon as it is provided to the model and outputs a processed "doc."
#
# <img src="https://d33wubrfki0l68.cloudfront.net/3ad0582d97663a1272ffc4ccf09f1c5b335b17e9/7f49c/pipeline-fde48da9b43661abcdf62ab70a546d71.svg">

# %%
# Processed Doc

doc = nlp(text)

# %%
# Words Object

words = [token.text for token in doc]
words[:5]
# Out:
# ['\ufeffCURRÍCUlS^', '\n', 'PAULISTA', 'II', 'II']

# %%
# Sentences Object

sentences = [sent.text for sent in doc.sents]
sentences[:5]
# Out:
# ['\ufeffCURRÍCUlS^\n',
#  'PAULISTA II II',
#  '\n',
#  'SECRETARIA DA EDUCAÇÃO DO ESTADO DE SÃO PAULO\n',
#  'CURRÍCULO']

# %% [markdown]
# ## Cleaning

# %%
# Remove Punctuation and Spaces
no_punct_or_space = [token for token in doc if token.is_punct == False and token.is_space == False]

# Remove Numbers and lower case everything
lower_alpha = [token.lower_ for token in no_punct_or_space if token.is_alpha == True]

# Remove Custom Stop Words (if needed)

#    custom_stopwords = ["assyrian", "babylon"]
#    custom_clean = [token for token in clean if token not in custom_stopwords]
#    custom_clean

# %%
# Cleaned Corpus

clean = [token.lower_ for token in no_punct_or_space if token.is_alpha == True and token.is_stop == False]
clean[:30]
# Out:
# ['paulista',
#  'ii',
#  'ii',
#  'secretaria',
#  'educação',
#  'paulo',
#  'currículo',
#  'paulista',
#  'etapa',
#  'ensino',
#  'médio',
#  'paulo',
#  'governo',
#  'governador',
#  'joão',
#  'dória',
#  'secretário',
#  'educação',
#  'rossieli',
#  'soares',
#  'silva',
#  'secretário',
#  'executivo',
#  'haroldo',
#  'corrêa',
#  'rocha',
#  'chefe',
#  'gabinete',
#  'renilda',
#  'peres']

# %% [markdown]
# ## Counting

# %%
print("Number of tokens in document: ", len(doc))
print("Number of tokens in cleaned document: ", len(clean))
print("Number of unique tokens in cleaned document: ", len(set(clean)))
# Out:
# Number of tokens in document:  119957
# Number of tokens in cleaned document:  52071
# Number of unique tokens in cleaned document:  6418

# %%
from collections import Counter

cleaned_counter = Counter(clean)
cleaned_counter.most_common(10)
# Out:
# [('diferentes', 469),
#  ('estudante', 435),
#  ('ensino', 341),
#  ('vida', 313),
#  ('processos', 299),
#  ('textos', 291),
#  ('social', 270),
#  ('conhecimentos', 270),
#  ('sociais', 269),
#  ('produção', 269)]

# %%
print(clean)
# Out:
# ['paulista', 'ii', 'ii', 'secretaria', 'educação', 'paulo', 'currículo', 'paulista', 'etapa', 'ensino', 'médio', 'paulo', 'governo', 'governador', 'joão', 'dória', 'secretário', 'educação', 'rossieli', 'soares', 'silva', 'secretário', 'executivo', 'haroldo', 'corrêa', 'rocha', 'chefe', 'gabinete', 'renilda', 'peres', 'lima', 'subsecretário', 'articulação', 'regional', 'henrique', 'cunha', 'pimentel', 'filho', 'coordenador', 'pedagógico', 'caetano', 'pansani', 'siqueira', 'coordenadora', 'escola', 'formação', 'aperfeiçoamento', 'profissionais', 'educação', 'cristina', 'cassia', 'mabelini', 'silva', 'coordenadora', 'gestão', 'recursos', 'humanos', 'cristty', 'anny', 'hayon', 'coordenador', 'informação', 'tecnologia', 'evidência', 'matrícula', 'thiago', 'guimarães', 'cardoso', 'coordenador', 'infraestrutura', 'serviços', 'escolares', 'daniel', 'medeiros', 'coordenador', 'orçamento', 'finanças', 'william', 'bezerra', 'melo', 'uníao', 'dirigentes', 'municipais', 'educação', 'presidente', 'undime', 'márcia', 'aparecida', 'bernardes', 'regionais', 'gde', 'sp', 'lélia', 'hartmann', 'torres', 'regionais', 'interior', 'celso', 'fernando', 'iversen', 'secretária', 'coordenação', 'técnica', 'maria', 'thereza', 'ferreira', 'cyirino', 'secretária', 'finanças', 'denize', 'jacob', 'paula', 'secretário', 'assuntos', 'jurídicos', 'lauro', 'alexandre', 'silva', 'oliveira', 'secretário', 'comunicação', 'ederson', 'marcelo', 'batista', 'ficha', 'técnica', 'currículo', 'paulista', 'etapa', 'ensino', 'médio', 'coordenadora', 'estadual', 'maria', 'adriana', 'pagan', 'coordenadora', 'estadual', 'maridalva', 'oliveira', 'amorim', 'bertacini', 'articuladora', 'estadual', 'ghisleine', 'trigo', 'silveira', 'assessor', 'técnico', 'gabinete', 'ensino', 'médio', 'gustavo', 'blanco', 'mendonça', 'coordenadora', 'etapa', 'ensino', 'médio', 'helena', 'claudia', 'soares', 'achilles', 'articuladora', 'itinerários', 'formativos', 'ana', 'joaquina', 'simões', 'sallares', 'mattos', 'carvalho', 'articuladores', 'itinerários', 'formativos', 'ept', 'fernanda', 'mello', 'demai', 'gilson', 'rede', 'articuladora', 'etapas', 'silvia', 'teixeira', 'bardy', 'redatores', 'linguagens', 'tecnologias', 'coordenador', 'marcos', 'rodrigues', 'ferreira', 'redatores', 'arte', 'eduardo', 'martins', 'kebbe', 'evania', 'rodrigues', 'moraes', 'escudeiro', 'educação', 'física', 'luiz', 'fernando', 'vagliengo', 'mirna', 'léia', 'violin', 'brandt', 'língua', 'inglesa', 'eliana', 'aparecida', 'oliveira', 'burian', 'emerson', 'thiago', 'kaishi', 'ono', 'língua', 'portuguesa', 'mara', 'lucia', 'david', 'mary', 'jacomine', 'silva', 'matemática', 'tecnologias', 'coordenador', 'joão', 'santos', 'vitalino', 'redatores', 'matemática', 'otávio', 'yoshio', 'yamanaka', 'vanderley', 'aparecido', 'cornatione', 'ciências', 'natureza', 'tecnologias', 'coordenador', 'carolina', 'santos', 'batista', 'murauskas', 'alexandra', 'fraga', 'vazquez', 'redatores', 'biologia', 'aparecida', 'kida', 'sanches', 'beatriz', 'felice', 'ponzio', 'física', 'ana', 'claudia', 'cossini', 'martins', 'jefferson', 'heleno', 'tsuchiya', 'química', 'cristiane', 'marani', 'coppini', 'natalina', 'fátima', 'mateus', 'ciências', 'humanas', 'sociais', 'aplicadas', 'coordenador', 'tânia', 'gonçalves', 'redatores', 'filosofia', 'erica', 'cristina', 'frau', 'geografia', 'sérgio', 'luiz', 'damiati', 'história', 'clarissa', 'bazzanelli', 'barradas', 'edi', 'wilson', 'silveira', 'sociologia', 'emerson', 'costa', 'colaboradores', 'adriana', 'santos', 'cunha', 'adriano', 'rodrigues', 'biajone', 'andréa', 'hohne', 'demonte', 'anna', 'penido', 'beatriz', 'santana', 'ferreira', 'cassia', 'moraes', 'targa', 'longo', 'claudia', 'berry', 'claudia', 'soraia', 'rocha', 'moura', 'danilo', 'scalambrini', 'isabel', 'cristina', 'theodoro', 'kátia', 'stocco', 'smole', 'laís', 'barbosa', 'moura', 'modesto', 'leticia', 'galtieri', 'ferreira', 'oliveira', 'luiz', 'carlos', 'tozetto', 'maria', 'paula', 'cintra', 'naves', 'raquel', 'maria', 'rodrigues', 'rodri ...
